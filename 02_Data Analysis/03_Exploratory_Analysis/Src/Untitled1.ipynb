# %%
import pandas as pd

# %%
height = pd.read_csv('heights.csv')
print(height.describe())

diabete = pd.read_csv('pima-indians-diabetes.data.csv')
print(diabete.head())

usaarrests = pd.read_csv('USArrests.csv')
print(usaarrests.head())

births = pd.read_csv('daily-total-female-births.csv')
print(births.head())
# Out:
#            HEIGHT
# count  379.000000
# mean    67.097625
# std      4.120502
# min     56.000000
# 25%     64.000000
# 50%     67.000000
# 75%     70.000000
# max     92.000000
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Class
# 0                     0.627   50      1
# 1                     0.351   31      0
# 2                     0.672   32      1
# 3                     0.167   21      0
# 4                     2.288   33      1
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# ...

# %% [markdown]
# # Descrevendo Dados Qualitativos
# * Class: 1 positivo para diabete
# * Class: 0 negativo para diabete

# %%
diabete['Class'].value_counts().plot(kind='bar')

# %%
diabete['Class'].value_counts().plot(kind='pie')

# %% [markdown]
# # Descrevendo Dados Quantitativos
# * Histograma
# * Área
# * Scatter
# * Line
# * Bloxplot
# * KDE

# %%
### Exemplos de gráficos
## Histogramas por cada coluna
print(usaarrests.hist())

## Histograma por coluna
print(usaarrests.hist(column='UrbanPop'))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f715774a198>]]
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f71576882e8>
# ...
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f71573b85f8>]]

# %%
#usaarrests.plot.area(x='Unnamed: 0',y='Rape')
#usaarrests.plot.area(y='Rape')
usaarrests.plot.area()

# %%
#Correlação baixa
usaarrests.plot.scatter(x='UrbanPop',y='Murder')
#Correlação Alta
usaarrests.plot.scatter(x='Murder',y='Assault')
# Out:
#             Murder   Assault  UrbanPop      Rape
# Murder    1.000000  0.801873  0.069573  0.563579
# Assault   0.801873  1.000000  0.258872  0.665241
# UrbanPop  0.069573  0.258872  1.000000  0.411341
# Rape      0.563579  0.665241  0.411341  1.000000

# %%
# Date  Births
births.plot.line(x='Date',y='Births')
births.plot.line(y='Births')

# %%
#BOX
usaarrests.plot.box()

# %%
usaarrests.plot.kde()

# %% [markdown]
# # Tendência Central
# * Média
# * Mediana
# * Moda

# %%
#tendencia central

print(usaarrests.describe())
print("Medianas")
print(usaarrests.median())
print("Moda")
print(usaarrests.mode())
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000
# Medianas
# Murder        7.25
# Assault     159.00
# UrbanPop     66.00
# Rape         20.10
# dtype: float64
# Moda
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama     2.1    120.0      66.0  14.9
# 1           Alaska     2.2      NaN      80.0  16.3
# 2          Arizona     2.6      NaN       NaN   NaN
# 3         Arkansas     6.0      NaN       NaN   NaN
# 4       California     9.0      NaN       NaN   NaN
# 5         Colorado    13.2      NaN       NaN   NaN
# ...

# %% [markdown]
# # Dispersão
# * Desvio médio
# * Variância
# * Desvio Padrão
# * Covariância

# %%
print(usaarrests.describe())

print("Desvio absoluto simples")
print(usaarrests.mad())
print("Variância")
print(usaarrests.var())
print("Desvio Padrão")
print(usaarrests.std())
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000
# Desvio absoluto simples
# Murder       3.64704
# Assault     71.18080
# UrbanPop    11.87520
# Rape         7.31312
# dtype: float64
# Variância
# Murder        18.970465
# Assault     6945.165714
# UrbanPop     209.518776
# Rape          87.729159
# dtype: float64
# Desvio Padrão
# Murder       4.355510
# Assault     83.337661
# UrbanPop    14.474763
# Rape         9.366385
# dtype: float64

# %%
meanaux=df.mean()
mean=meanaux[0]

stdaux=df.std()
std=stdaux[0]

print(mean-(2*std))
print(mean-(std))
print(mean+(std))
print(mean+(2*std))


df68=df.loc[(df[0] >= (mean-std)) & (df[0] <=  (mean+std))]

print(df68.describe())

df95=df.loc[(df[0] >= (mean-(2*std))) & (df[0] <=  (mean+(2*std)))]

print(df95.describe())

df26=df.loc[(((df[0] >= (mean-(2*std))) & (df[0] <= (mean-(std)))) | (((df[0] <=  (mean+(2*std)))) & (df[0] >=  (mean+(std)))))]

print(df26.describe())


#df68=df.loc[(df[0] >= -std & df[0] <= std)]
#print(df68.describe())
# Out:
# 87.98490542108287
# 91.98792982017018
#                  0
# count  6855.000000
# mean     89.968790
# std       1.068826
# min      87.985454
# 25%      89.090057
# 50%      89.967600
# 75%      90.829280
# max      91.987673
#                  0
# count  9526.000000
# mean     89.984377
# std       1.743951
# min      85.985271
# 25%      88.728501
# 50%      89.980134
# 75%      91.228772
# max      93.987368
#                  0
# count  2671.000000
# mean     90.024381
# std       2.813365
# min      85.985271
# 25%      87.322874
# 50%      92.005654
# 75%      92.661283
# max      93.987368
# 85.98339322153922
# 87.98490542108287
# 91.98792982017018
# 93.98944201971383

# %% [markdown]
# # Distribuição Normal

# %%
values= np.random.normal(90,2, 10000)
df = pd.DataFrame(values)
print(df.head())
print(df.describe())
print("Mediana")
print(df.median())
df.hist()
df.plot.density()
df.plot.box()
# Out:
#            0
# 0  88.713049
# 1  89.651993
# 2  92.860231
# 3  85.204298
# 4  90.217622
#                   0
# count  10000.000000
# mean      89.986418
# std        2.001512
# min       82.176340
# 25%       88.652450
# 50%       89.980821
# 75%       91.303432
# max       97.429415
# Mediana
# 0    89.980821
# dtype: float64

# %%
import scipy.stats as ss
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 5000)
mu = 0
sigma = 1

y_pdf = ss.norm.pdf(x, mu, sigma) # normal

mu = 1
sigma = 2
y_cdf = ss.norm.pdf(x, mu, sigma) # the normal cdf


plt.plot(x, y_pdf, label='normal 1')
plt.plot(x, y_cdf, label='normal 2')
plt.legend();

# %%
import scipy.stats as ss
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 5000)
mu = 0
sigma = 1

y_pdf = ss.poisson.pdf(x, mu, sigma) # normal

mu = 1
sigma = 2
y_cdf = ss.norm.pdf(x, mu, sigma) # the normal cdf


plt.plot(x, y_pdf, label='normal 1')
plt.plot(x, y_cdf, label='normal 2')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-309-397f316e8f0d> in <module>
#       6 sigma = 1
#       7
# ----> 8 y_pdf = ss.poisson.pdf(x, mu, sigma) # normal
#       9
#      10 mu = 1
#
# AttributeError: 'poisson_gen' object has no attribute 'pdf'

# %%
#Marcando quartis
bin_labels_5 = ['1', '2', '3', '4','5','6']
df['quartile'] = pd.qcut(df[0], q=[0, 0.05, .25, .5, .75, .95, 1], labels=bin_labels_5)

df2=df.loc[df['quartile'] == '4']
print(df2)
print(df2.describe())
print(df2.head())
# Out:
#               0 quartile
# 4     90.217622        4
# 13    90.975729        4
# 15    91.096110        4
# 18    90.912509        4
# 33    90.168612        4
# ...         ...      ...
# 9974  90.290196        4
# 9977  91.169179        4
# 9994  90.202362        4
# 9997  90.988254        4
# 9999  90.459788        4
#
# [2500 rows x 2 columns]
#                  0
# count  2500.000000
# mean     90.611225
# std       0.380145
# min      89.981065
# 25%      90.269074
# 50%      90.608576
# 75%      90.928300
# max      91.303350
#             0 quartile
# 4   90.217622        4
# 13  90.975729        4
# 15  91.096110        4
# 18  90.912509        4
# 33  90.168612        4

# %% [markdown]
# # Distribuição Poisson

# %%
values= np.random.normal(3,5,5000)
dfP = pd.DataFrame(values)


dfP['id']=range(0, 5000)

dfP.head()
dfP[0].hist()

dfP2 =dfP.sort_values(by=[0])

dfP2.plot.scatter(x='id',y=0)


#dfP.plot.density()
#dfP.plot.line()

# %%
stat, p = normaltest(df)

# interpret
alpha = 0.05
print('Statistics=%.3f, p=%.3f' % (stat, p))

if p > alpha:
    print('falha para rejeitar H0 (curva gaussiana)')
else:
    print('rejeitar H0 (não é curva gaussiana)')
# Out:
# Statistics=2.927, p=0.231
# Sample looks Gaussian (fail to reject H0)

# %%
print("Variância")
print(from_csv.var())
print("CoVariância")
print(from_csv.cov())
# Out:
# Variância
# Murder        18.970465
# Assault     6945.165714
# UrbanPop     209.518776
# Rape          87.729159
# dtype: float64
# CoVariância
#               Murder      Assault    UrbanPop        Rape
# Murder     18.970465   291.062367    4.386204   22.991412
# Assault   291.062367  6945.165714  312.275102  519.269061
# UrbanPop    4.386204   312.275102  209.518776   55.768082
# Rape       22.991412   519.269061   55.768082   87.729159

# %%
#births['1959-01'].plot.line()
#births2 =births.iloc(births['Date'] >= '1959-01')
#births.plot.line()
#births2.plot.line()

# %%
print(usaarrests.hist())
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f71567c8828>
# ...

# %%
height = pd.read_csv('houses.csv')
print(height.describe())
print(height.hist(column='52000'))
# Out:
#               52000
# count  9.999900e+04
# mean   1.743880e+05
# std    3.514649e+05
# min    1.500000e+02
# 25%    7.400000e+04
# 50%    1.290000e+05
# 75%    2.070000e+05
# max    4.846572e+07
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f715806d780>]]

# %%
height = pd.read_csv('heights.csv')
print(height.describe())
print(height.hist())
# Out:
#                 earn       height           ed          age
# count    1192.000000  1192.000000  1192.000000  1192.000000
# mean    23154.773490    66.915154    13.504195    41.378356
# std     19472.296925     3.853968     2.420175    15.867428
# min       200.000000    57.503219     3.000000    18.000000
# 25%     10000.000000    64.009746    12.000000    29.000000
# 50%     20000.000000    66.451265    13.000000    38.000000
# 75%     30000.000000    69.848100    16.000000    51.000000
# max    200000.000000    77.051282    18.000000    91.000000
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x7f715938b5f8>
# ...

# %%
from scipy.stats import normaltest
#from scipy.stats import shapiro
#stat, p = shapiro(height['ed'])
#stat, p = normaltest(height['height'])
stat, p = normaltest(height['52000'])



# interpret
alpha = 0.05
print('Statistics=%.3f, p=%.3f' % (stat, p))
#print(stat, p)
# interpret
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=341029.940, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
climatedata = pd.read_csv('subplots.csv')
print(climatedata.describe())
print(climatedata.mean())
print(climatedata.median())
      
print(climatedata.hist(column='south pole co2'))
print(climatedata.hist())
print(climatedata['south pole co2'].mean())
print(climatedata['south pole co2'].median())
# Out:
#        mauna loa co2  south pole co2  heat content  +2σ heat content  \
# count     685.000000      685.000000    685.000000        685.000000
# mean      350.457241      346.503650      0.040277          0.137151
# std        25.000696       33.045861      1.460931          1.396604
# min       312.660000        0.000000     -9.538462         -6.666667
# 25%       327.660000      325.910000      0.000000          0.000000
# 50%       348.050000      345.160000      0.000000          0.000000
# 75%       370.520000      367.190000      0.000000          0.000000
# max       401.770000      395.270000     13.333333         13.641026
#
#        -2σ heat content  -2σ temperature anomaly  temperature anomaly  \
# count        685.000000               685.000000           685.000000
# mean          -0.055999                 0.005195             0.010549
# std            1.657029                 0.061005             0.070440
# ...

# %%
from scipy.stats import shapiro
stat, p = shapiro(climatedata['south pole co2'])



# interpret
alpha = 0.05
print('Statistics=%.3f, p=%.3f' % (stat, p))
#print(stat, p)
# interpret
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.674, p=0.000
# Sample does not look Gaussian (reject H0)

# %%
import numpy as np
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.default_rng().normal(mu, sigma, 1000)

from scipy.stats import shapiro
stat, p = shapiro(s)



# interpret
alpha = 0.05
print('Statistics=%.3f, p=%.3f' % (stat, p))
#print(stat, p)
# interpret
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-6d62f2e31668> in <module>
#       1 import numpy as np
#       2 mu, sigma = 0, 0.1 # mean and standard deviation
# ----> 3 s = np.random.default_rng().normal(mu, sigma, 1000)
#       4
#       5 from scipy.stats import shapiro
#
# AttributeError: module 'numpy.random' has no attribute 'default_rng'

# %%
from_csv = pd.read_csv('USArrests.csv')
print(from_csv.head())

from_csv2 = from_csv.sample(30)

#from_csv4 =from_csv3.sort_values(by=['Assault'])

#print(from_csv['Assault'])
#print(from_csv2['Assault'])

# Example of the Mann-Whitney U Test
from scipy.stats import mannwhitneyu

#data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
#data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = mannwhitneyu(from_csv['Assault'], from_csv2['Assault'])
#stat, p = mannwhitneyu(from_csv['Assault'], from_csv['Rape'])

#stat, p = mannwhitneyu(data1, data2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6
# stat=740.500, p=0.464
# Probably the same distribution

# %%
import requests
import io

#url="https://raw.githubusercontent.com/jbrownlee/Datasets/master/adult-all.csv"

#s = requests.get(url).content
#ds = pd.read_csv(io.StringIO(s.decode('utf-8')))
#print(ds.describe())

ds = pd.read_csv('adult-all.csv')
print(ds.describe())
ds.hist(column='13')

print(ds['13'].median())
print(ds['13'].mean())

#ds['77516'].plot.line()
#ds['77516'].plot.scatter()

# %%
diabete = pd.read_csv('pima-indians-diabetes.data.csv')
print(diabete.head())

from_csv = pd.read_csv('USArrests.csv')
print(from_csv.head())

# %%
#plot para dados qualitativos
#Class: 1 positivo para diabete 0 negativo
diabete['Class'].value_counts().plot('bar')

# %%
# Descrevendo dados

# %%
#Intervalos
print(from_csv.info())
#Intervalos
print(from_csv.describe())
print(from_csv.median())
print("Variância")
print(from_csv.var())
print("Correlação")
print(from_csv.corr())
print("CoVariância")
print(from_csv.cov())
print("Standard Error")
print(from_csv.sem())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# Unnamed: 0    50 non-null object
# Murder        50 non-null float64
# Assault       50 non-null int64
# UrbanPop      50 non-null int64
# Rape          50 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB
# None
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000
# Murder        7.25
# Assault     159.00
# UrbanPop     66.00
# Rape         20.10
# dtype: float64
# Variância
# Murder        18.970465
# Assault     6945.165714
# ...

# %%
#rom_csv.hist(column='Rape')
from_csv.hist(column='Assault')
from_csv.hist(column='UrbanPop')

# %%
from_csv.hist()

# %%
from scipy.stats import kurtosis, skew, mode

print(kurtosis(from_csv['Murder']))
print(skew(from_csv['Murder']))

print(kurtosis(from_csv['Assault']))
print(skew(from_csv['Assault']))

print(kurtosis(from_csv['Rape']))
print(skew(from_csv['Rape']))

print(kurtosis(from_csv['UrbanPop']))
print(skew(from_csv['UrbanPop']))

#print(kurtosis(ds['13']))
#print(skew(ds['13']))

# %%
from_csv2 =from_csv.sort_values(by=['Assault'])
from_csv2.plot.line(x='Assault',y='Murder')
from_csv2.plot.line(x='Assault',y='UrbanPop')

# %%
from_csv3 = from_csv2.sample(20)
from_csv4 =from_csv3.sort_values(by=['Assault'])
from_csv4.plot.line(x='Assault',y='Murder')
from_csv4.plot.line(x='Assault',y='UrbanPop')

# %%
from_csv.plot.area(x='Unnamed: 0',y='Rape')

# %%
from_csv.plot.bar(x='UrbanPop',y='Murder')

# %%
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
#Teste t com uma amostra

from scipy import stats

female_doctor_bps = [128, 127, 118, 115, 144, 142, 133, 140, 132, 131, 
                     111, 132, 149, 122, 139, 119, 136, 129, 126, 128]
stats.ttest_1samp(female_doctor_bps, 120)

# %%
#teste t com duas amostras

female_doctor_bps = [128, 127, 118, 115, 144, 142, 133, 140, 132, 131, 
                     111, 132, 149, 122, 139, 119, 136, 129, 126, 128]

male_consultant_bps = [118, 115, 112, 120, 124, 130, 123, 110, 120, 121,
                      123, 125, 129, 130, 112, 117, 119, 120, 123, 128]

stats.ttest_ind(female_doctor_bps, male_consultant_bps)

# %%
#Teste t
control = [8.0, 7.1, 6.5, 6.7, 7.2, 5.4, 4.7, 8.1, 6.3, 4.8]
treatment = [9.9, 7.9, 7.6, 6.8, 7.1, 9.9, 10.5, 9.7, 10.9, 8.2]

stats.ttest_rel(control, treatment)

# %%
# parameters are k, n and p

from scipy.stats import binom

#probabilidade binomial derivada de benoulli

#Escolher K amostras, de uma população de tamanho n com probabilidade p
#k=3, n=10, p=0.1
#exemplo: escolher 3 pessoas que utilizam a mao esquerda de um total de 10 , supondo probabilidade 0.1 de uma pessoa escrever 
#com a mao esquerda

binom.pmf(3, 10, 0.1)

# %%
#plot das probabilidades:

plt.bar(range(11), [binom.pmf(x, 10, 0.1) for x in range(11)])
plt.xlabel('k')
plt.ylabel('P(X=k)')
plt.title('Binomial PMF')
plt.show()

# %%
#curva poisson

from scipy.stats import poisson

import matplotlib.pyplot as plt

_lambda = 2.5

plt.bar(range(11), [poisson.pmf(k, _lambda) for k in range(11)])
plt.xlabel('k (number of goals)')
plt.ylabel('P(X=k)')
plt.title('Poisson PMF')
plt.show()

# %%
import numpy as np
from scipy.stats import norm

import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)
mean, var, skew, kurt = norm.stats(moments='mvsk')
rv = norm()

x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
ax.plot(x, norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')

ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
#skew

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.DataFrame({" rating": [1, 2, 3, 4, 6, 7, 9, 9, 9, 10], "dummy": range(10)})

f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})

mean=df[' rating'].mean()
median=df[' rating'].median()
mode=df[' rating'].mode().get_values()[0]


sns.distplot(df[" rating"], ax=ax_hist)
ax_hist.axvline(mean, color='r', linestyle='--')
ax_hist.axvline(median, color='g', linestyle='-')
ax_hist.axvline(mode, color='b', linestyle='-')

plt.legend({'Mean':mean,'Median':median,'Mode':mode})

ax_box.set(xlabel='')
plt.show()

# %%
from scipy.stats import skew 

diabete = pd.read_csv('pima-indians-diabetes.data.csv')
print(diabete.head())
print(diabete.describe())
print("média")
print(diabete.mean())
print("mediana")
print(diabete.median())

# %%
#t=[2, 8, 0, 4, 1, 9, 9, 0]
#skew(t)

from scipy.stats import skewtest

skewtest([2, 8, 0, 4, 1, 9, 9, 0])

# %%
#SkinThickness
#BloodPressure

diabete.hist(column='BloodPressure', bins=20)
#direita 
#media=69
#mediana=72

s_array = diabete[["BloodPressure"]].to_numpy()

print(s_array)
#print( '\nSkewness for data : ', skew(s_array)) 

diabete['BloodPressure2'] =0
diabete['BloodPressure2'] = diabete[diabete['BloodPressure']>0]
print(diabete['BloodPressure2'].max())
print(diabete['BloodPressure2'].min())
print(diabete['BloodPressure2'].mean())
print(diabete['BloodPressure2'].median())
diabete.hist(column='BloodPressure2', bins=20)

# %%
diabete.hist(column='Age', bins=50)
#direita 
#media=33
#mediana=29

# %%
diabete.plot.bar(x='Age')

# %%
from scipy import stats
#a = np.array([ 0.7972,  0.0767,  0.4383,  0.7866,  0.8091,0.1954,  0.6307,  0.6599,  0.1065,  0.0508])
a = [ 0.7972,  0.0767,  0.4383,  0.7866,  0.8091,0.1954,  0.6307,  0.6599,  0.1065,  0.0508]
b = np.sort(a)
print(b)
zs=stats.zscore(b)

#array([ 1.1273, -1.247 , -0.0552,  1.0923,  1.1664, -0.8559,  0.5786,
#        0.6748, -1.1488, -1.3324])
print(zs)
plt.plot(zs,b) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()
