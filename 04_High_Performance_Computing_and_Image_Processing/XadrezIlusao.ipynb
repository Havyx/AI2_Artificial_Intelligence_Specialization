# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('figs/xadrez.jpg')

# %% [markdown]
# ### Provando que a cor do quadrado "A" e igual a cor do quadrado "B".

# %%
fig = plt.figure(figsize=[100, 200])
plt.imshow(img)

# %%
img.shape
# Out:
# (838, 1078, 3)

# %%
plt.imshow(img)

# %%
img_b = img[450:500, 500: 550].copy()
plt.imshow(img_b)

# %%
img_b[10,10]
# Out:
# array([120, 120, 120], dtype=uint8)

# %%
img_a = img[260:310, 550:600].copy()
plt.imshow(img_a)

# %%
img_a[10,10]
# Out:
# array([120, 120, 120], dtype=uint8)

# %%
print(img_a[0,0] == img_b[0,0])
# Out:
# [ True  True  True]
