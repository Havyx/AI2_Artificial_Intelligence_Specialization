# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !ls figs
# Out:
# 'ls' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
img = cv2.imread("./figs/messi5.jpg")
img.shape
# Out:
# (342, 548, 3)

# %%
print(img[0, 0]) #Acessa o primeiro PIXEL da imagem que retorna 3 valores dos canais BGR
# Out:
# [36 40 45]

# %%
print(img[0]) # Acessa a linha 0 com 548 pixels, onde cada pixes tem 3 valores de canais BGR
# Out:
# [[36 40 45]
#  [41 45 50]
#  [44 48 53]
#  ...
#  [55 55 55]
#  [54 54 54]
#  [53 53 53]]

# %%
print(img[:,0]) # acessa a primeira coluna de pixels que retorna 342 pixels onde cada pixel tem 3 canais de cor
# Out:
# [[ 36  40  45]
#  [ 38  41  49]
#  [ 41  43  53]
#  ...
#  [ 62 144 101]
#  [ 56 138  95]
#  [ 49 131  88]]

# %%
print(img[0,0,0]) #Acessa o canal B do primeiro pixel da imagem
# Out:
# 36

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
ROI = img[285:336, 335:390].copy()
plt.imshow(cv2.cvtColor(ROI, cv2.COLOR_BGR2RGB))

# %%
ROI.shape
# Out:
# (51, 55, 3)

# %%
greenPixels = img[285:336, 335:336]
plt.imshow(greenPixels)

# %%
greenPixels.shape
# Out:
# (51, 1, 3)

# %%
for i in range(0, 55):
    img[285:336, 335+i:336+i] = greenPixels
plt.imshow(img)

# %%
ROI.shape
# Out:
# (51, 55, 3)

# %%
img[285:336, 135:190] = ROI
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import imutils

rotacionar = imutils.rotate_bound(img, 60)
plt.imshow(rotacionar)

# %%
plt.imshow(imutils.resize(img, 1080))

# %%
linha, coluna, canais = img.shape
